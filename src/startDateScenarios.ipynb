# %%
import pickle
import importlib
import pandas as pd

import src.utils.dataLoader as data_loader
importlib.reload(data_loader)
from src.utils.dataLoader import DataLoader
import src.utils.state as state
import src.utils.plottings as plotting
import src.utils.scenarioCalculator as scenarioCalculator
import src.utils.dataConverter as dataConverter
import src.utils.config as config
from src.utils.config import GlobalConfig
from src.utils.scenarios import Scenarios
#from src.utils.models import Scenario
import src.utils.projectInitializer as projectInitializer
import src.utils.modelBase as modelBase
import src.utils.models as models

importlib.reload(models)
importlib.reload(plotting)
importlib.reload(state)
importlib.reload(scenarioCalculator)
importlib.reload(dataConverter)
importlib.reload(config)
# Out:
# <module 'src.utils.config' from 'C:\\Users\\CSURITA\\PycharmProjects\\PythonProject\\counterfactual-analysis-vzv\\src\\utils\\config.py'>

# %%
Scenario = models.Scenario
ALL_SCENARIOS: list[Scenario] = []

# %%
loader = DataLoader()
loader.load_data()
projectInitializer.init_all(loader)
modelBase.calculate_baseline()

# %% [markdown]
# ## Start vaccination 1 year earlier (2018.09.01)

# %%
scenario_starting_0_year_minus: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    "test starting 0 years minus", 1, GlobalConfig.START_OF_VACCINATION, True)

# %%
plotting.plot_model_actual_scat_comparison(scenario_starting_0_year_minus)
plotting.plot_model_results_age_range_in_range(scenario_starting_0_year_minus.I, 0, 4, scenario_starting_0_year_minus.name)
plotting.plot_model_results_age_range_in_range(scenario_starting_0_year_minus.I, 5, 9, scenario_starting_0_year_minus.name)
plotting.plot_model_results_age_range_in_range(scenario_starting_0_year_minus.I, 10, 12, scenario_starting_0_year_minus.name)

# %%
scenario_1_year_minus: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.STARTING_1_YEAR_MINUS, 1, GlobalConfig.START_OF_VACCINATION + pd.DateOffset(years=-1), True)
ALL_SCENARIOS.append(scenario_1_year_minus)

# %%
plotting.plot_model_actual_scat_comparison(scenario_1_year_minus)
plotting.plot_model_results_age_range_in_range(scenario_1_year_minus.I, 0, 4, scenario_1_year_minus.name)
plotting.plot_model_results_age_range_in_range(scenario_1_year_minus.I, 5, 9, scenario_1_year_minus.name)
plotting.plot_model_results_age_range_in_range(scenario_1_year_minus.I, 10, 12, scenario_1_year_minus.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_1_year_minus.weekly_i_series, scenario_1_year_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_1_year_minus.I, 0, 4, scenario_1_year_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_1_year_minus.I, 5, 9, scenario_1_year_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_1_year_minus.I, 10, 12, scenario_1_year_minus.name)

# %% [markdown]
# ## Start vaccination 2 years earlier (2017.09.01)

# %%
scenario_2_years_minus: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.STARTING_2_YEAR_MINUS, 1, GlobalConfig.START_OF_VACCINATION + pd.DateOffset(years=-2), True)
ALL_SCENARIOS.append(scenario_2_years_minus)

# %%
plotting.plot_model_actual_scat_comparison(scenario_2_years_minus)
plotting.plot_model_results_age_range_in_range(scenario_2_years_minus.I, 0, 4, scenario_2_years_minus.name)
plotting.plot_model_results_age_range_in_range(scenario_2_years_minus.I, 5, 9, scenario_2_years_minus.name)
plotting.plot_model_results_age_range_in_range(scenario_2_years_minus.I, 10, 12, scenario_2_years_minus.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_2_years_minus.weekly_i_series, scenario_2_years_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_2_years_minus.I, 0, 4, scenario_2_years_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_2_years_minus.I, 5, 9, scenario_2_years_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_2_years_minus.I, 10, 12, scenario_2_years_minus.name)

# %% [markdown]
# ## Start vaccination 3 years earlier (2016.09.01)

# %%
scenario_3_years_minus: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.STARTING_3_YEAR_MINUS, 1, GlobalConfig.START_OF_VACCINATION + pd.DateOffset(years=-3), True)
ALL_SCENARIOS.append(scenario_3_years_minus)

# %%
plotting.plot_model_actual_scat_comparison(scenario_3_years_minus)
plotting.plot_model_results_age_range_in_range(scenario_3_years_minus.I, 0, 4, scenario_3_years_minus.name)
plotting.plot_model_results_age_range_in_range(scenario_3_years_minus.I, 5, 9, scenario_3_years_minus.name)
plotting.plot_model_results_age_range_in_range(scenario_3_years_minus.I, 10, 12, scenario_3_years_minus.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_3_years_minus.weekly_i_series, scenario_3_years_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_3_years_minus.I, 0, 4, scenario_3_years_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_3_years_minus.I, 5, 9, scenario_3_years_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_3_years_minus.I, 10, 12, scenario_3_years_minus.name)

# %% [markdown]
# ## Start vaccination 5 years earlier (2014.09.01)

# %%
scenario_5_years_minus: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.STARTING_5_YEAR_MINUS, 1, GlobalConfig.START_OF_VACCINATION + pd.DateOffset(years=-5), True)
ALL_SCENARIOS.append(scenario_5_years_minus)

# %%
plotting.plot_model_actual_scat_comparison(scenario_5_years_minus)
plotting.plot_model_results_age_range_in_range(scenario_5_years_minus.I, 0, 4, scenario_5_years_minus.name)
plotting.plot_model_results_age_range_in_range(scenario_5_years_minus.I, 5, 9, scenario_5_years_minus.name)
plotting.plot_model_results_age_range_in_range(scenario_5_years_minus.I, 10, 12, scenario_5_years_minus.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_5_years_minus.weekly_i_series, scenario_5_years_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_5_years_minus.I, 0, 4, scenario_5_years_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_5_years_minus.I, 5, 9, scenario_5_years_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_5_years_minus.I, 10, 12, scenario_5_years_minus.name)

# %% [markdown]
# ## Start vaccination 8 years earlier (2011.09.01)

# %%
scenario_8_years_minus: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.STARTING_8_YEAR_MINUS, 1, GlobalConfig.START_OF_VACCINATION + pd.DateOffset(years=-8), True)
ALL_SCENARIOS.append(scenario_8_years_minus)

# %%
plotting.plot_model_actual_scat_comparison(scenario_8_years_minus)
plotting.plot_model_results_age_range_in_range(scenario_8_years_minus.I, 0, 4, scenario_8_years_minus.name)
plotting.plot_model_results_age_range_in_range(scenario_8_years_minus.I, 5, 9, scenario_8_years_minus.name)
plotting.plot_model_results_age_range_in_range(scenario_8_years_minus.I, 10, 12, scenario_8_years_minus.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_8_years_minus.weekly_i_series, scenario_8_years_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_8_years_minus.I, 0, 4, scenario_8_years_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_8_years_minus.I, 5, 9, scenario_8_years_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_8_years_minus.I, 10, 12, scenario_8_years_minus.name)

# %% [markdown]
# ## Start vaccination 13 years earlier (2006.09.01)

# %%
scenario_13_years_minus: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.STARTING_13_YEAR_MINUS, 1, GlobalConfig.START_OF_VACCINATION + pd.DateOffset(years=-13), True)
ALL_SCENARIOS.append(scenario_13_years_minus)

# %%
plotting.plot_model_actual_scat_comparison(scenario_13_years_minus)
plotting.plot_model_results_age_range_in_range(scenario_13_years_minus.I, 0, 4, scenario_13_years_minus.name)
plotting.plot_model_results_age_range_in_range(scenario_13_years_minus.I, 5, 9, scenario_13_years_minus.name)
plotting.plot_model_results_age_range_in_range(scenario_13_years_minus.I, 10, 12, scenario_13_years_minus.name)

# %%
plotting.plot_cumulative_i_and_v(scenario_13_years_minus, pd.Timestamp(2007,1,1))

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_13_years_minus.weekly_i_series, scenario_13_years_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_13_years_minus.I, 0, 4, scenario_13_years_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_13_years_minus.I, 5, 9, scenario_13_years_minus.name)
plotting.plot_annual_number_of_cases_for_age_groups(scenario_13_years_minus.I, 10, 12, scenario_13_years_minus.name)

# %%
scenario_13_years_minus_test: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.STARTING_13_YEAR_MINUS, 0.4, GlobalConfig.START_OF_VACCINATION + pd.DateOffset(years=-13), True)

# %%
plotting.plot_model_actual_scat_comparison(scenario_13_years_minus_test)
plotting.plot_model_results_age_range_in_range(scenario_13_years_minus_test.I, 0, 4, scenario_13_years_minus.name)
plotting.plot_model_results_age_range_in_range(scenario_13_years_minus_test.I, 5, 9, scenario_13_years_minus.name)
plotting.plot_model_results_age_range_in_range(scenario_13_years_minus_test.I, 10, 12, scenario_13_years_minus.name)

# %% [markdown]
# ## Start vaccination 1 year later (2020.09.01)

# %%
scenario_1_years_plus: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.STARTING_1_YEAR_PLUS, 1, GlobalConfig.START_OF_VACCINATION + pd.DateOffset(years=1), True)

# %%
plotting.plot_model_actual_scat_comparison(scenario_1_years_plus)
plotting.plot_model_results_age_range_in_range(scenario_1_years_plus.I, 0, 4, scenario_1_years_plus.name)
plotting.plot_model_results_age_range_in_range(scenario_1_years_plus.I, 5, 9, scenario_1_years_plus.name)
plotting.plot_model_results_age_range_in_range(scenario_1_years_plus.I, 10, 12, scenario_1_years_plus.name)

# %% [markdown]
# ## Start vaccination 2 years later (2021.09.01)

# %%
scenario_2_years_plus: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.STARTING_2_YEAR_PLUS, 1, GlobalConfig.START_OF_VACCINATION + pd.DateOffset(years=2), True)

# %%
plotting.plot_model_actual_scat_comparison(scenario_2_years_plus)
plotting.plot_model_results_age_range_in_range(scenario_2_years_plus.I, 0, 4, scenario_2_years_plus.name)
plotting.plot_model_results_age_range_in_range(scenario_2_years_plus.I, 5, 9, scenario_2_years_plus.name)
plotting.plot_model_results_age_range_in_range(scenario_2_years_plus.I, 10, 12, scenario_2_years_plus.name)

# %% [markdown]
# ## Start vaccination 3 years later (2022.09.01)

# %%
scenario_3_years_plus: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.STARTING_3_YEAR_PLUS, 1, GlobalConfig.START_OF_VACCINATION + pd.DateOffset(years=3), True)

# %%
plotting.plot_model_actual_scat_comparison(scenario_3_years_plus)
plotting.plot_model_results_age_range_in_range(scenario_3_years_plus.I, 0, 4, scenario_3_years_plus.name)
plotting.plot_model_results_age_range_in_range(scenario_3_years_plus.I, 5, 9, scenario_3_years_plus.name)
plotting.plot_model_results_age_range_in_range(scenario_3_years_plus.I, 10, 12, scenario_3_years_plus.name)

# %%
plotting.plot_model_results_age_range_in_range(scenario_1_years_plus.I, 0, 2, scenario_1_years_plus.name)
plotting.plot_model_results_age_range_in_range(scenario_2_years_plus.I, 0, 2, scenario_2_years_plus.name)
plotting.plot_model_results_age_range_in_range(scenario_3_years_plus.I, 0, 2, scenario_3_years_plus.name)

# %% [markdown]
# ## Mimic italian case

# %%
vento_scenario: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    "Vento scenario", 0.7, pd.Timestamp(2005,1,1), True)
# Out:
# number of vaccinated individuals can not be calculated before 2006-02-03 00:00:00

# %%
plotting.plot_model_actual_scat_comparison(vento_scenario)
plotting.plot_model_results_age_range_in_range(vento_scenario.I, 0, 4, vento_scenario.name)
plotting.plot_model_results_age_range_in_range(vento_scenario.I, 5, 9, vento_scenario.name)
plotting.plot_model_results_age_range_in_range(vento_scenario.I, 10, 12, vento_scenario.name)

# %% [markdown]
# ## Save results

# %%
serializable = [
    {
        "name": s.name,
        "S": s.S,
        "I": s.I,
        "V1": s.V1,
        "V2": s.V2
    }
    for s in ALL_SCENARIOS
]

with open("results/start_date_scenarios.pkl", "wb") as f:
    pickle.dump(serializable, f)
