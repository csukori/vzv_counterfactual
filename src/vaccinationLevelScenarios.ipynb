# %%
import pickle
import importlib

import src.utils.dataLoader as data_loader
importlib.reload(data_loader)
from src.utils.dataLoader import DataLoader
import src.utils.state as state
import src.utils.plottings as plotting
import src.utils.scenarioCalculator as scenarioCalculator
import src.utils.dataConverter as dataConverter
import src.utils.config as config
from src.utils.config import GlobalConfig
from src.utils.scenarios import Scenarios
#from src.utils.models import Scenario
import src.utils.projectInitializer as projectInitializer
import src.utils.modelBase as modelBase
import src.utils.models as models

importlib.reload(models)
importlib.reload(plotting)
importlib.reload(state)
importlib.reload(scenarioCalculator)
importlib.reload(dataConverter)
importlib.reload(config)
# Out:
# <module 'src.utils.config' from 'C:\\Users\\CSURITA\\PycharmProjects\\PythonProject\\counterfactual-analysis-vzv\\src\\utils\\config.py'>

# %%
Scenario = models.Scenario
ALL_SCENARIOS: list[Scenario] = []

# %%
loader = DataLoader()
loader.load_data()
projectInitializer.init_all(loader)
modelBase.calculate_baseline()

# %% [markdown]
#  ## Incidences without vaccination

# %%
scenario_no_vacc = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.NO_VACCINATION, 0, GlobalConfig.START_OF_VACCINATION, True)

# %%
plotting.plot_model_actual_scat_comparison(scenario_no_vacc)
plotting.plot_model_results_age_range_in_range(scenario_no_vacc.I, 0, 4, scenario_no_vacc.name)
plotting.plot_model_results_age_range_in_range(scenario_no_vacc.I, 5, 9, scenario_no_vacc.name)
plotting.plot_model_results_age_range_in_range(scenario_no_vacc.I, 10, 12, scenario_no_vacc.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_no_vacc.weekly_i_series, scenario_no_vacc.name)

# %%
plotting.plot_annual_number_of_cases_for_age_groups(scenario_no_vacc.I, 0, 4, scenario_no_vacc.name)

# %% [markdown]
# ## Vaccination level = 0.75

# %%
scenario_vacc_level_75: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.VACC_LEVEL_75, 0.75, GlobalConfig.START_OF_VACCINATION, True)

# %%
plotting.plot_model_actual_scat_comparison(scenario_vacc_level_75)
plotting.plot_model_results_age_range_in_range(scenario_vacc_level_75.I, 0, 4, scenario_vacc_level_75.name)
plotting.plot_model_results_age_range_in_range(scenario_vacc_level_75.I, 5, 9, scenario_vacc_level_75.name)
plotting.plot_model_results_age_range_in_range(scenario_vacc_level_75.I, 10, 12, scenario_vacc_level_75.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_vacc_level_75.weekly_i_series, scenario_vacc_level_75.name)

# %% [markdown]
# ## Vaccination level = 0.5

# %%
scenario_vacc_level_50: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.VACC_LEVEL_50, 0.50, GlobalConfig.START_OF_VACCINATION, True)

# %%
plotting.plot_model_actual_scat_comparison(scenario_vacc_level_50)
plotting.plot_model_results_age_range_in_range(scenario_vacc_level_50.I, 0, 4, scenario_vacc_level_50.name)
plotting.plot_model_results_age_range_in_range(scenario_vacc_level_50.I, 5, 9, scenario_vacc_level_50.name)
plotting.plot_model_results_age_range_in_range(scenario_vacc_level_50.I, 10, 12, scenario_vacc_level_50.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_vacc_level_50.weekly_i_series, scenario_vacc_level_50.name)

# %% [markdown]
# ## Vaccination level = 0.25

# %%
scenario_vacc_level_25: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.VACC_LEVEL_25, 0.25, GlobalConfig.START_OF_VACCINATION, True)

# %%
plotting.plot_model_actual_scat_comparison(scenario_vacc_level_25)
plotting.plot_model_results_age_range_in_range(scenario_vacc_level_25.I, 0, 4, scenario_vacc_level_25.name)
plotting.plot_model_results_age_range_in_range(scenario_vacc_level_25.I, 5, 9, scenario_vacc_level_25.name)
plotting.plot_model_results_age_range_in_range(scenario_vacc_level_25.I, 10, 12, scenario_vacc_level_25.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_vacc_level_25.weekly_i_series, scenario_vacc_level_25.name)

# %% [markdown]
# ## Additional scenarios

# %%
vacc_level_95 = scenarioCalculator.calculate_number_of_cases_for_scenario("vaccination rate: 95%", 0.95, GlobalConfig.START_OF_VACCINATION, True)
vacc_level_90 = scenarioCalculator.calculate_number_of_cases_for_scenario("vaccination rate: 90%", 0.90, GlobalConfig.START_OF_VACCINATION, True)
vacc_level_85 = scenarioCalculator.calculate_number_of_cases_for_scenario("vaccination rate: 85%", 0.85, GlobalConfig.START_OF_VACCINATION, True)
vacc_level_80 = scenarioCalculator.calculate_number_of_cases_for_scenario("vaccination rate: 80%", 0.80, GlobalConfig.START_OF_VACCINATION, True)
vacc_level_70 = scenarioCalculator.calculate_number_of_cases_for_scenario("vaccination rate: 70%", 0.70, GlobalConfig.START_OF_VACCINATION, True)
vacc_level_65 = scenarioCalculator.calculate_number_of_cases_for_scenario("vaccination rate: 65%", 0.65, GlobalConfig.START_OF_VACCINATION, True)
vacc_level_60 = scenarioCalculator.calculate_number_of_cases_for_scenario("vaccination rate: 60%", 0.60, GlobalConfig.START_OF_VACCINATION, True)
vacc_level_55 = scenarioCalculator.calculate_number_of_cases_for_scenario("vaccination rate: 55%", 0.55, GlobalConfig.START_OF_VACCINATION, True)
vacc_level_45 = scenarioCalculator.calculate_number_of_cases_for_scenario("vaccination rate: 45%", 0.45, GlobalConfig.START_OF_VACCINATION, True)
vacc_level_40 = scenarioCalculator.calculate_number_of_cases_for_scenario("vaccination rate: 40%", 0.40, GlobalConfig.START_OF_VACCINATION, True)
vacc_level_35 = scenarioCalculator.calculate_number_of_cases_for_scenario("vaccination rate: 35%", 0.35, GlobalConfig.START_OF_VACCINATION, True)
vacc_level_30 = scenarioCalculator.calculate_number_of_cases_for_scenario("vaccination rate: 30%", 0.30, GlobalConfig.START_OF_VACCINATION, True)
vacc_level_20 = scenarioCalculator.calculate_number_of_cases_for_scenario("vaccination rate: 20%", 0.20, GlobalConfig.START_OF_VACCINATION, True)
vacc_level_15 = scenarioCalculator.calculate_number_of_cases_for_scenario("vaccination rate: 15%", 0.15, GlobalConfig.START_OF_VACCINATION, True)
vacc_level_10 = scenarioCalculator.calculate_number_of_cases_for_scenario("vaccination rate: 10%", 0.10, GlobalConfig.START_OF_VACCINATION, True)
vacc_level_5 = scenarioCalculator.calculate_number_of_cases_for_scenario("vaccination rate: 5%", 0.05, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS = [scenario_no_vacc, vacc_level_5, vacc_level_10, vacc_level_15, vacc_level_20, scenario_vacc_level_25, vacc_level_30, vacc_level_35, vacc_level_40, vacc_level_45, scenario_vacc_level_50, vacc_level_55, vacc_level_60, vacc_level_65, vacc_level_70, scenario_vacc_level_75, vacc_level_80, vacc_level_85, vacc_level_90, vacc_level_95]

# %% [markdown]
# ## Save results

# %%
serializable = [
    {
        "name": s.name,
        "S": s.S,
        "I": s.I,
        "V1": s.V1,
        "V2": s.V2
    }
    for s in ALL_SCENARIOS
]

with open("results/vaccination_level_scenarios.pkl", "wb") as f:
    pickle.dump(serializable, f)
