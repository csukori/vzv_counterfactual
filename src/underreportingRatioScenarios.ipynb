# %%
import pickle
import importlib

import src.utils.dataLoader as data_loader
importlib.reload(data_loader)
from src.utils.dataLoader import DataLoader
import src.utils.state as state
import src.utils.plottings as plotting
import src.utils.scenarioCalculator as scenarioCalculator
import src.utils.dataConverter as dataConverter
import src.utils.config as config
from src.utils.config import GlobalConfig
from src.utils.scenarios import Scenarios
#from src.utils.models import Scenario
import src.utils.projectInitializer as projectInitializer
import src.utils.modelBase as modelBase
import src.utils.models as models

importlib.reload(models)
importlib.reload(plotting)
importlib.reload(state)
importlib.reload(scenarioCalculator)
importlib.reload(dataConverter)
importlib.reload(config)
importlib.reload(projectInitializer)

# %%
Scenario = models.Scenario
ALL_SCENARIOS: list[Scenario] = []

# %%
loader = DataLoader()
loader.load_data()

# %% [markdown]
# ## Detection rate: 0.5

# %%
projectInitializer.init_all(loader, 0.5)
modelBase.calculate_baseline()
ALL_SCENARIOS.append(state.BASELINE_SCENARIO)
state.BASELINE_SCENARIO.name = Scenarios.DETECTION_50_BASELINE

# %% [markdown]
# ### Incidences without vaccination

# %%
scenario_50_no_vacc = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_50_NO_VACCINATION, 0, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_50_no_vacc)

# %%
plotting.plot_model_actual_scat_comparison(scenario_50_no_vacc)
plotting.plot_model_results_age_range_in_range(scenario_50_no_vacc.I, 0, 4, scenario_50_no_vacc.name)
plotting.plot_model_results_age_range_in_range(scenario_50_no_vacc.I, 5, 9, scenario_50_no_vacc.name)
plotting.plot_model_results_age_range_in_range(scenario_50_no_vacc.I, 10, 12, scenario_50_no_vacc.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_50_no_vacc.weekly_i_series, scenario_50_no_vacc.name)

# %%
plotting.plot_annual_number_of_cases_for_age_groups(scenario_50_no_vacc.I, 0, 4, scenario_50_no_vacc.name)

# %% [markdown]
# ## Detection rate: 0.6

# %%
projectInitializer.init_all(loader, 0.6)
modelBase.calculate_baseline()

# %% [markdown]
# ### Incidences without vaccination

# %%
scenario_60_no_vacc = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_60_NO_VACCINATION, 0, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_60_no_vacc)

# %%
plotting.plot_model_actual_scat_comparison(scenario_60_no_vacc)
plotting.plot_model_results_age_range_in_range(scenario_60_no_vacc.I, 0, 4, scenario_60_no_vacc.name)
plotting.plot_model_results_age_range_in_range(scenario_60_no_vacc.I, 5, 9, scenario_60_no_vacc.name)
plotting.plot_model_results_age_range_in_range(scenario_60_no_vacc.I, 10, 12, scenario_60_no_vacc.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_60_no_vacc.weekly_i_series, scenario_60_no_vacc.name)

# %%
plotting.plot_annual_number_of_cases_for_age_groups(scenario_60_no_vacc.I, 0, 4, scenario_60_no_vacc.name)

# %% [markdown]
# ### Vaccination level = 0.75

# %%
scenario_60_vacc_level_75: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_60_VACC_LEVEL_75, 0.75, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_60_vacc_level_75)

# %%
plotting.plot_model_actual_scat_comparison(scenario_60_vacc_level_75)
plotting.plot_model_results_age_range_in_range(scenario_60_vacc_level_75.I, 0, 4, scenario_60_vacc_level_75.name)
plotting.plot_model_results_age_range_in_range(scenario_60_vacc_level_75.I, 5, 9, scenario_60_vacc_level_75.name)
plotting.plot_model_results_age_range_in_range(scenario_60_vacc_level_75.I, 10, 12, scenario_60_vacc_level_75.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_60_vacc_level_75.weekly_i_series, scenario_60_vacc_level_75.name)

# %% [markdown]
# ### Vaccination level = 0.25

# %%
scenario_60_vacc_level_25: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_60_VACC_LEVEL_25, 0.25, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_60_vacc_level_25)

# %%
plotting.plot_model_actual_scat_comparison(scenario_60_vacc_level_25)
plotting.plot_model_results_age_range_in_range(scenario_60_vacc_level_25.I, 0, 4, scenario_60_vacc_level_25.name)
plotting.plot_model_results_age_range_in_range(scenario_60_vacc_level_25.I, 5, 9, scenario_60_vacc_level_25.name)
plotting.plot_model_results_age_range_in_range(scenario_60_vacc_level_25.I, 10, 12, scenario_60_vacc_level_25.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_60_vacc_level_25.weekly_i_series, scenario_60_vacc_level_25.name)

# %% [markdown]
# ### Vaccination level = 0.1

# %%
scenario_60_vacc_level_10: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_60_VACC_LEVEL_10, 0.1, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_60_vacc_level_10)

# %%
plotting.plot_model_actual_scat_comparison(scenario_60_vacc_level_10)
plotting.plot_model_results_age_range_in_range(scenario_60_vacc_level_10.I, 0, 4, scenario_60_vacc_level_10.name)
plotting.plot_model_results_age_range_in_range(scenario_60_vacc_level_10.I, 5, 9, scenario_60_vacc_level_10.name)
plotting.plot_model_results_age_range_in_range(scenario_60_vacc_level_10.I, 10, 12, scenario_60_vacc_level_10.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_60_vacc_level_10.weekly_i_series, scenario_60_vacc_level_10.name)

# %% [markdown]
# ## Detection rate: 0.7

# %%
projectInitializer.init_all(loader, 0.7)
modelBase.calculate_baseline()
ALL_SCENARIOS.append(state.BASELINE_SCENARIO)
state.BASELINE_SCENARIO.name = Scenarios.DETECTION_60_BASELINE

# %% [markdown]
# ### Incidences without vaccination

# %%
scenario_70_no_vacc = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_70_NO_VACCINATION, 0, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_70_no_vacc)

# %%
plotting.plot_model_actual_scat_comparison(scenario_70_no_vacc)
plotting.plot_model_results_age_range_in_range(scenario_70_no_vacc.I, 0, 4, scenario_70_no_vacc.name)
plotting.plot_model_results_age_range_in_range(scenario_70_no_vacc.I, 5, 9, scenario_70_no_vacc.name)
plotting.plot_model_results_age_range_in_range(scenario_70_no_vacc.I, 10, 12, scenario_70_no_vacc.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_70_no_vacc.weekly_i_series, scenario_70_no_vacc.name)

# %%
plotting.plot_annual_number_of_cases_for_age_groups(scenario_70_no_vacc.I, 0, 4, scenario_70_no_vacc.name)

# %% [markdown]
# ### Vaccination level = 0.75

# %%
scenario_70_vacc_level_75: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_70_VACC_LEVEL_75, 0.75, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_70_vacc_level_75)

# %%
plotting.plot_model_actual_scat_comparison(scenario_70_vacc_level_75)
plotting.plot_model_results_age_range_in_range(scenario_70_vacc_level_75.I, 0, 4, scenario_70_vacc_level_75.name)
plotting.plot_model_results_age_range_in_range(scenario_70_vacc_level_75.I, 5, 9, scenario_70_vacc_level_75.name)
plotting.plot_model_results_age_range_in_range(scenario_70_vacc_level_75.I, 10, 12, scenario_70_vacc_level_75.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_70_vacc_level_75.weekly_i_series, scenario_70_vacc_level_75.name)

# %% [markdown]
# ### Vaccination level = 0.25

# %%
scenario_70_vacc_level_25: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_70_VACC_LEVEL_25, 0.25, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_70_vacc_level_25)

# %%
plotting.plot_model_actual_scat_comparison(scenario_70_vacc_level_25)
plotting.plot_model_results_age_range_in_range(scenario_70_vacc_level_25.I, 0, 4, scenario_70_vacc_level_25.name)
plotting.plot_model_results_age_range_in_range(scenario_70_vacc_level_25.I, 5, 9, scenario_70_vacc_level_25.name)
plotting.plot_model_results_age_range_in_range(scenario_70_vacc_level_25.I, 10, 12, scenario_70_vacc_level_25.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_70_vacc_level_25.weekly_i_series, scenario_70_vacc_level_25.name)

# %% [markdown]
# ### Vaccination level = 0.1

# %%
scenario_70_vacc_level_10: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_70_VACC_LEVEL_10, 0.1, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_70_vacc_level_10)

# %%
plotting.plot_model_actual_scat_comparison(scenario_70_vacc_level_10)
plotting.plot_model_results_age_range_in_range(scenario_70_vacc_level_10.I, 0, 4, scenario_70_vacc_level_10.name)
plotting.plot_model_results_age_range_in_range(scenario_70_vacc_level_10.I, 5, 9, scenario_70_vacc_level_10.name)
plotting.plot_model_results_age_range_in_range(scenario_70_vacc_level_10.I, 10, 12, scenario_70_vacc_level_10.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_70_vacc_level_10.weekly_i_series, scenario_70_vacc_level_10.name)

# %% [markdown]
# ## Detection rate: 0.8

# %%
projectInitializer.init_all(loader, 0.8)
modelBase.calculate_baseline()
ALL_SCENARIOS.append(state.BASELINE_SCENARIO)
state.BASELINE_SCENARIO.name = Scenarios.DETECTION_80_BASELINE

# %% [markdown]
# ### Incidences without vaccination

# %%
scenario_80_no_vacc = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_80_NO_VACCINATION, 0, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_80_no_vacc)

# %%
plotting.plot_model_actual_scat_comparison(scenario_80_no_vacc)
plotting.plot_model_results_age_range_in_range(scenario_80_no_vacc.I, 0, 4, scenario_80_no_vacc.name)
plotting.plot_model_results_age_range_in_range(scenario_80_no_vacc.I, 5, 9, scenario_80_no_vacc.name)
plotting.plot_model_results_age_range_in_range(scenario_80_no_vacc.I, 10, 12, scenario_80_no_vacc.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_80_no_vacc.weekly_i_series, scenario_80_no_vacc.name)

# %%
plotting.plot_annual_number_of_cases_for_age_groups(scenario_80_no_vacc.I, 0, 4, scenario_80_no_vacc.name)

# %% [markdown]
# ### Vaccination level = 0.75

# %%
scenario_80_vacc_level_75: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_80_VACC_LEVEL_75, 0.75, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_80_vacc_level_75)

# %%
plotting.plot_model_actual_scat_comparison(scenario_80_vacc_level_75)
plotting.plot_model_results_age_range_in_range(scenario_80_vacc_level_75.I, 0, 4, scenario_80_vacc_level_75.name)
plotting.plot_model_results_age_range_in_range(scenario_80_vacc_level_75.I, 5, 9, scenario_80_vacc_level_75.name)
plotting.plot_model_results_age_range_in_range(scenario_80_vacc_level_75.I, 10, 12, scenario_80_vacc_level_75.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_80_vacc_level_75.weekly_i_series, scenario_80_vacc_level_75.name)

# %% [markdown]
# ### Vaccination level = 0.25

# %%
scenario_80_vacc_level_25: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_80_VACC_LEVEL_25, 0.25, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_80_vacc_level_25)

# %%
plotting.plot_model_actual_scat_comparison(scenario_80_vacc_level_25)
plotting.plot_model_results_age_range_in_range(scenario_80_vacc_level_25.I, 0, 4, scenario_80_vacc_level_25.name)
plotting.plot_model_results_age_range_in_range(scenario_80_vacc_level_25.I, 5, 9, scenario_80_vacc_level_25.name)
plotting.plot_model_results_age_range_in_range(scenario_80_vacc_level_25.I, 10, 12, scenario_80_vacc_level_25.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_80_vacc_level_25.weekly_i_series, scenario_80_vacc_level_25.name)

# %% [markdown]
# ### Vaccination level = 0.1

# %%
scenario_80_vacc_level_10: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_80_VACC_LEVEL_10, 0.1, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_80_vacc_level_10)

# %%
plotting.plot_model_actual_scat_comparison(scenario_80_vacc_level_10)
plotting.plot_model_results_age_range_in_range(scenario_80_vacc_level_10.I, 0, 4, scenario_80_vacc_level_10.name)
plotting.plot_model_results_age_range_in_range(scenario_80_vacc_level_10.I, 5, 9, scenario_80_vacc_level_10.name)
plotting.plot_model_results_age_range_in_range(scenario_80_vacc_level_10.I, 10, 12, scenario_80_vacc_level_10.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_80_vacc_level_10.weekly_i_series, scenario_80_vacc_level_10.name)

# %% [markdown]
# ## Detection rate: 0.9

# %%
projectInitializer.init_all(loader, 0.9)
modelBase.calculate_baseline()
ALL_SCENARIOS.append(state.BASELINE_SCENARIO)
state.BASELINE_SCENARIO.name = Scenarios.DETECTION_90_BASELINE

# %% [markdown]
# ### Incidences without vaccination

# %%
scenario_90_no_vacc = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_90_NO_VACCINATION, 0, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_90_no_vacc)

# %%
plotting.plot_model_actual_scat_comparison(scenario_90_no_vacc)
plotting.plot_model_results_age_range_in_range(scenario_90_no_vacc.I, 0, 4, scenario_90_no_vacc.name)
plotting.plot_model_results_age_range_in_range(scenario_90_no_vacc.I, 5, 9, scenario_90_no_vacc.name)
plotting.plot_model_results_age_range_in_range(scenario_90_no_vacc.I, 10, 12, scenario_90_no_vacc.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_90_no_vacc.weekly_i_series, scenario_90_no_vacc.name)

# %%
plotting.plot_annual_number_of_cases_for_age_groups(scenario_90_no_vacc.I, 0, 4, scenario_90_no_vacc.name)

# %% [markdown]
# ### Vaccination level = 0.75

# %%
scenario_90_vacc_level_75: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_90_VACC_LEVEL_75, 0.75, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_90_vacc_level_75)

# %%
plotting.plot_model_actual_scat_comparison(scenario_90_vacc_level_75)
plotting.plot_model_results_age_range_in_range(scenario_90_vacc_level_75.I, 0, 4, scenario_90_vacc_level_75.name)
plotting.plot_model_results_age_range_in_range(scenario_90_vacc_level_75.I, 5, 9, scenario_90_vacc_level_75.name)
plotting.plot_model_results_age_range_in_range(scenario_90_vacc_level_75.I, 10, 12, scenario_90_vacc_level_75.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_90_vacc_level_75.weekly_i_series, scenario_90_vacc_level_75.name)

# %% [markdown]
# ### Vaccination level = 0.25

# %%
scenario_90_vacc_level_25: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_90_VACC_LEVEL_25, 0.25, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_90_vacc_level_25)

# %%
plotting.plot_model_actual_scat_comparison(scenario_90_vacc_level_25)
plotting.plot_model_results_age_range_in_range(scenario_90_vacc_level_25.I, 0, 4, scenario_90_vacc_level_25.name)
plotting.plot_model_results_age_range_in_range(scenario_90_vacc_level_25.I, 5, 9, scenario_90_vacc_level_25.name)
plotting.plot_model_results_age_range_in_range(scenario_90_vacc_level_25.I, 10, 12, scenario_90_vacc_level_25.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_90_vacc_level_25.weekly_i_series, scenario_90_vacc_level_25.name)

# %% [markdown]
# ## Vaccination level = 0.1

# %%
scenario_100_vacc_level_10: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_90_VACC_LEVEL_10, 0.1, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_100_vacc_level_10)

# %%
plotting.plot_model_actual_scat_comparison(scenario_100_vacc_level_10)
plotting.plot_model_results_age_range_in_range(scenario_100_vacc_level_10.I, 0, 4, scenario_100_vacc_level_10.name)
plotting.plot_model_results_age_range_in_range(scenario_100_vacc_level_10.I, 5, 9, scenario_100_vacc_level_10.name)
plotting.plot_model_results_age_range_in_range(scenario_100_vacc_level_10.I, 10, 12, scenario_100_vacc_level_10.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_100_vacc_level_10.weekly_i_series, scenario_100_vacc_level_10.name)

# %% [markdown]
# ## Detection rate: 1

# %%
projectInitializer.init_all(loader, 1)
modelBase.calculate_baseline()
ALL_SCENARIOS.append(state.BASELINE_SCENARIO)
state.BASELINE_SCENARIO.name = Scenarios.DETECTION_100_BASELINE

# %% [markdown]
# ### Incidences without vaccination

# %%
scenario_100_no_vacc = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_100_NO_VACCINATION, 0, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_100_no_vacc)

# %%
plotting.plot_model_actual_scat_comparison(scenario_100_no_vacc)
plotting.plot_model_results_age_range_in_range(scenario_100_no_vacc.I, 0, 4, scenario_100_no_vacc.name)
plotting.plot_model_results_age_range_in_range(scenario_100_no_vacc.I, 5, 9, scenario_100_no_vacc.name)
plotting.plot_model_results_age_range_in_range(scenario_100_no_vacc.I, 10, 12, scenario_100_no_vacc.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_100_no_vacc.weekly_i_series, scenario_100_no_vacc.name)

# %%
plotting.plot_annual_number_of_cases_for_age_groups(scenario_100_no_vacc.I, 0, 4, scenario_100_no_vacc.name)

# %% [markdown]
# ### Vaccination level = 0.75

# %%
scenario_100_vacc_level_75: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_100_VACC_LEVEL_75, 0.75, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_100_vacc_level_75)

# %%
plotting.plot_model_actual_scat_comparison(scenario_100_vacc_level_75)
plotting.plot_model_results_age_range_in_range(scenario_100_vacc_level_75.I, 0, 4, scenario_100_vacc_level_75.name)
plotting.plot_model_results_age_range_in_range(scenario_100_vacc_level_75.I, 5, 9, scenario_100_vacc_level_75.name)
plotting.plot_model_results_age_range_in_range(scenario_100_vacc_level_75.I, 10, 12, scenario_100_vacc_level_75.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_100_vacc_level_75.weekly_i_series, scenario_100_vacc_level_75.name)

# %% [markdown]
# ### Vaccination level = 0.25

# %%
scenario_100_vacc_level_25: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_100_VACC_LEVEL_25, 0.25, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_100_vacc_level_25)

# %%
plotting.plot_model_actual_scat_comparison(scenario_100_vacc_level_25)
plotting.plot_model_results_age_range_in_range(scenario_100_vacc_level_25.I, 0, 4, scenario_100_vacc_level_25.name)
plotting.plot_model_results_age_range_in_range(scenario_100_vacc_level_25.I, 5, 9, scenario_100_vacc_level_25.name)
plotting.plot_model_results_age_range_in_range(scenario_100_vacc_level_25.I, 10, 12, scenario_100_vacc_level_25.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_100_vacc_level_25.weekly_i_series, scenario_100_vacc_level_25.name)

# %% [markdown]
# ### Vaccination level = 0.1

# %%
scenario_100_vacc_level_10: Scenario = scenarioCalculator.calculate_number_of_cases_for_scenario(
    Scenarios.DETECTION_100_VACC_LEVEL_10, 0.1, GlobalConfig.START_OF_VACCINATION, True)
ALL_SCENARIOS.append(scenario_100_vacc_level_10)

# %%
plotting.plot_model_actual_scat_comparison(scenario_100_vacc_level_10)
plotting.plot_model_results_age_range_in_range(scenario_100_vacc_level_10.I, 0, 4, scenario_100_vacc_level_10.name)
plotting.plot_model_results_age_range_in_range(scenario_100_vacc_level_10.I, 5, 9, scenario_100_vacc_level_10.name)
plotting.plot_model_results_age_range_in_range(scenario_100_vacc_level_10.I, 10, 12, scenario_100_vacc_level_10.name)

# %%
plotting.plot_compare_scenario_to_actual_case(scenario_100_vacc_level_10.weekly_i_series, scenario_100_vacc_level_10.name)

# %% [markdown]
# ## Save results

# %%
serializable = [
    {
        "name": s.name,
        "S": s.S,
        "I": s.I,
        "V1": s.V1,
        "V2": s.V2
    }
    for s in ALL_SCENARIOS
]

with open("results/detection_rate_scenarios.pkl", "wb") as f:
    pickle.dump(serializable, f)
